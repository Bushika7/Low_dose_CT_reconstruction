# %% [markdown]
# ## Coming soon

# %% [markdown]
# In this notebook I will implement the following article: https://openaccess.thecvf.com/content/CVPR2022W/CVMI/papers/Buchholz_Fourier_Image_Transformer_CVPRW_2022_paper.pdf
